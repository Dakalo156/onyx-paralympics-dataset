# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Load Raw Data

# %%
athlete_medals_data = pd.read_excel("raw_data\medal_athlete.xlsx", sheet_name="Data")
athlete_medals_data.head()
# Out:
#   games_code  games_year      games_city  City_latitude  City_longitude  \
# 0     PG2000        2000          Sydney       -33.8688        151.2093
# 1     PG2000        2000          Sydney       -33.8688        151.2093
# 2     PG2000        2000          Sydney       -33.8688        151.2093
# 3     PG2016        2016  Rio de Janeiro       -22.9068        -43.1729
# 4     PG2016        2016  Rio de Janeiro       -22.9068        -43.1729
#
#   games_country  Country_latitude  Country_longitude games_continent  \
# 0     Australia        -25.274398         133.775136         Oceania
# 1     Australia        -25.274398         133.775136         Oceania
# 2     Australia        -25.274398         133.775136         Oceania
# 3        Brazil        -14.235004         -51.925280        Americas
# 4        Brazil        -14.235004         -51.925280        Americas
#
#    games_start  ... athletes            event   medal  npc npc_new  npc_name  \
# ...

# %%
athlete_medals_dict = pd.read_excel(
    "raw_data\medal_athlete.xlsx", sheet_name="Data Dictionary", names=["column_name", "explanation"], header=None
)
athlete_medals_dict
# Out:
#            column_name                                        explanation
# 0           games_code                        The year and type of games.
# 1           games_year                       The year the games were held
# 2           games_city          The city that hosted the Paralympic Games
# 3        City_latitude                          Latitude of the host city
# 4       City_longitude                         Longitude of the host city
# 5        games_country                                       Host country
# 6     Country_latitude                       Latitude of the host country
# 7    Country_longitude                      Longitude of the host country
# 8      games_continent                      Continent of the host country
# 9          games_start                              Day the games started
# 10           games_end                                Day the games ended
# 11        games_season                             Summer or winter games
# ...
